# %% [markdown]
# # Introduction to UNIQ for APIC-EM
# ## Overview

# %% [markdown]
# This notebook shows how to use the uniq python library with APIC-EM.

# %% [markdown]
# ## Getting Started
# The first requirement is to import a NbClientManager to connect to APIC-EM

# %%
import json
import requests.exceptions

# this is the client manager used to connect to APIC-EM
from uniq.apis.nb.client_manager import NbClientManager

# this will be the ip/dns name of APIC, the user/password credentials
# stored in current directory
from apic_config import APIC, APIC_USER, APIC_PASSWORD

# %% [markdown]
# Next we create a connection, and check for obvious errors.

# %%
# create the connection to APIC-EM
try:
    apic = NbClientManager(
                server=APIC,
                username=APIC_USER,
                password=APIC_PASSWORD,
                connect=True)

except requests.exceptions.HTTPError as exc_info:
    if exc_info.response.status_code == 401:
        print('Authentication Failed. Please provide valid username/password.')
    else:
        print('HTTP Status Code {code}. Reason: {reason}'.format(
                    code=exc_info.response.status_code,
                    reason=exc_info.response.reason))
    exit(1)
except requests.exceptions.ConnectionError:
    print('Connection aborted. Please check if the host {host} is available.'.format(host=APIC))
    exit(1)

# %% [markdown]
# If you print the connection, you will see the server/username/password and version of the API

# %%
print(apic)
# Out:
# [APIC: <server:sandboxapic.cisco.com> <username:devnetuser> <password:Cisco123!> <version:v1>]

# %% [markdown]
# ## First API Request
# This example gets all of the network devices from the controller inventory.
#
# ### Accessing network-devices on APIC-EM

# %%
# this method will get all network devices
network_devices  = apic.networkdevice.getAllNetworkDevice()

# %%
# now pretty print it
# serialize turns object into a json dict.
# we do not normally do this, but shows the structure maps to a dictionary
print(json.dumps(apic.serialize(network_devices), indent=2))
# Out:
# {
#   "version": "1.0",
#   "response": [
#     {
#       "macAddress": "54:78:1a:8e:28:c0",
#       "lastUpdated": "2017-06-27 17:01:44",
#       "location": "13e2a474-b010-43df-ac57-7761b2ede2f3",
#       "lineCardCount": "1",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FOC1637Y3FJ",
#       "instanceUuid": "8dbd8068-1091-4cde-8cf5-d1b58dc5c9c7",
#       "snmpContact": "",
#       "lineCardId": "b77af8c6-bfa2-4388-9cbc-5e36f72090bf",
#       "family": "Switches and Hubs",
#       "apManagerInterfaceIp": "",
#       "tagCount": "2",
#       "type": "Cisco Catalyst 2960C-8PC-L Switch",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "roleSource": "MANUAL",
#       "managementIpAddress": "165.10.1.39",
#       "platformId": "WS-C2960C-8PC-L",
#       "locationName": "prague",
#       "id": "8dbd8068-1091-4cde-8cf5-d1b58dc5c9c7",
#       "role": "ACCESS",
#       "bootDateTime": "2016-11-18 07:54:31",
#       "softwareVersion": "15.2(2.5.72)E4",
#       "hostname": "AHEC-2960C1",
#       "lastUpdateTime": 1498582904890,
#       "interfaceCount": "11",
#       "memorySize": "59556224",
#       "series": "Cisco Catalyst 2960-C Series Switches",
#       "snmpLocation": "",
#       "upTime": "16:11:38.75",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     },
#     {
#       "macAddress": "68:bc:0c:63:4a:b0",
#       "lastUpdated": "2017-06-27 17:01:56",
#       "location": "c5f52ca3-3682-4788-903f-875bf665138d",
#       "collectionStatus": "Managed",
#       "serialNumber": "FGL1548S2YF",
#       "instanceUuid": "cd6d9b24-839b-4d58-adfe-3fdf781e1782",
#       "snmpContact": "",
#       "family": "Unified AP",
#       "hostname": "AP7081.059f.19ca",
#       "series": "Cisco 3500I Series Unified Access Points",
#       "type": "Cisco 3500I Unified Access Point",
#       "inventoryStatusDetail": "NA",
#       "roleSource": "AUTO",
#       "managementIpAddress": "10.1.14.3",
#       "platformId": "AIR-CAP3502I-A-K9",
#       "locationName": "data-_center_sj",
#       "id": "cd6d9b24-839b-4d58-adfe-3fdf781e1782",
#       "role": "ACCESS",
#       "apManagerInterfaceIp": "10.1.14.2",
#       "softwareVersion": "8.1.14.16",
#       "tunnelUdpPort": "16666",
#       "lastUpdateTime": 1498582916082,
#       "tagCount": "1",
#       "memorySize": "NA",
#       "errorCode": "null",
#       "snmpLocation": "default location",
#       "reachabilityStatus": "Reachable",
#       "reachabilityFailureReason": "NA"
#     },
#     {
#       "macAddress": "64:a0:e7:d4:9b:c1",
#       "lastUpdated": "2017-06-27 17:01:56",
#       "lineCardId": "cbfd87b9-a8a2-48a8-8296-2947dbf81de8",
#       "lineCardCount": "1",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FOC1537W1ZY",
#       "instanceUuid": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#       "snmpContact": "",
#       "hostname": "Branch-Access1",
#       "family": "Switches and Hubs",
#       "apManagerInterfaceIp": "",
#       "tagCount": "1",
#       "type": "Cisco Catalyst 29xx Stack-able Ethernet Switch",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "roleSource": "AUTO",
#       "managementIpAddress": "10.2.1.17",
#       "platformId": "WS-C2960S-48LPS-L",
#       "id": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#       "role": "ACCESS",
#       "bootDateTime": "2016-04-13 03:02:46",
#       "softwareVersion": "12.2(55)SE3",
#       "lastUpdateTime": 1498582916367,
#       "interfaceCount": "55",
#       "memorySize": "73969000",
#       "series": "Cisco Catalyst 2960 Series Switches",
#       "snmpLocation": "",
#       "upTime": "219 days, 21:09:28.84",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     },
#     {
#       "macAddress": "7c:0e:ce:9f:3c:d9",
#       "lastUpdated": "2017-06-27 17:01:44",
#       "lineCardId": "b913fc7b-ecda-4e8d-b96b-c46cc82cd6a8",
#       "lineCardCount": "1",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FTX1840ALC1",
#       "instanceUuid": "0dd240fd-5cca-4774-a801-9f1c04edcc70",
#       "snmpContact": "",
#       "hostname": "Branch-Router1",
#       "family": "Routers",
#       "apManagerInterfaceIp": "",
#       "tagCount": "2",
#       "type": "Cisco 2911 Integrated Services Router G2",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "roleSource": "AUTO",
#       "managementIpAddress": "10.2.2.1",
#       "platformId": "CISCO2911/K9",
#       "id": "0dd240fd-5cca-4774-a801-9f1c04edcc70",
#       "role": "BORDER ROUTER",
#       "bootDateTime": "2016-05-28 00:31:46",
#       "softwareVersion": "15.2(4)M6a",
#       "lastUpdateTime": 1498582904519,
#       "interfaceCount": "7",
#       "memorySize": "300214800",
#       "series": "Cisco 2900 Series Integrated Services Routers G2",
#       "snmpLocation": "",
#       "upTime": "174 days, 23:37:05.56",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     },
#     {
#       "macAddress": "f0:7f:06:bb:dc:81",
#       "lastUpdated": "2017-06-27 17:01:24",
#       "lineCardId": "94da60d6-5fc3-4613-bce7-7bc03e517647",
#       "lineCardCount": "1",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FTX1840ALBY",
#       "instanceUuid": "6ce631db-9212-4587-867f-b8f3aed1702d",
#       "snmpContact": "",
#       "hostname": "Branch-Router2",
#       "family": "Routers",
#       "apManagerInterfaceIp": "",
#       "tagCount": "1",
#       "type": "Cisco 2911 Integrated Services Router G2",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "roleSource": "AUTO",
#       "managementIpAddress": "10.2.2.2",
#       "platformId": "CISCO2911/K9",
#       "id": "6ce631db-9212-4587-867f-b8f3aed1702d",
#       "role": "BORDER ROUTER",
#       "bootDateTime": "2016-05-28 00:29:46",
#       "softwareVersion": "15.2(4)M6a",
#       "lastUpdateTime": 1498582884927,
#       "interfaceCount": "7",
#       "memorySize": "300246160",
#       "series": "Cisco 2900 Series Integrated Services Routers G2",
#       "snmpLocation": "",
#       "upTime": "174 days, 23:49:53.28",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     },
#     {
#       "roleSource": "MANUAL",
#       "lastUpdated": "2017-06-27 17:02:58",
#       "lineCardCount": "1",
#       "collectionStatus": "Partial Collection Failure",
#       "serialNumber": "FTX1840ALC0",
#       "instanceUuid": "d337811b-d371-444c-a49f-9e2791f955b4",
#       "snmpContact": "",
#       "lineCardId": "41a03d20-585c-4158-b5da-89125e592148",
#       "family": "Routers",
#       "platformId": "CISCO2911/K9",
#       "hostname": "Branch2-Router.yourdomain.com",
#       "series": "Cisco 2900 Series Integrated Services Routers G2",
#       "type": "Cisco 2911 Integrated Services Router G2",
#       "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#       "managementIpAddress": "218.1.100.100",
#       "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#       "softwareVersion": "15.2(4)M6a",
#       "tagCount": "1",
#       "id": "d337811b-d371-444c-a49f-9e2791f955b4",
#       "role": "ACCESS",
#       "bootDateTime": "2015-11-30 23:53:04",
#       "apManagerInterfaceIp": "",
#       "lastUpdateTime": 1498582978173,
#       "interfaceCount": "8",
#       "memorySize": "300217616",
#       "errorCode": "DEV-UNREACHED",
#       "snmpLocation": "",
#       "upTime": "354 days, 0:18:52.75",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": "SNMP Connectivity Failed"
#     },
#     {
#       "macAddress": "f0:29:29:5c:30:e2",
#       "lastUpdated": "2017-06-27 17:01:56",
#       "location": "811ca696-a959-423e-b6d2-2506eba4410a",
#       "lineCardCount": "2",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FOC1703V36B",
#       "instanceUuid": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#       "snmpContact": "",
#       "lineCardId": "4e3ad63f-36ac-4807-b2a9-e377ffc3b503, 2afe376a-b613-4695-82ba-3ed0030c37e6",
#       "family": "Switches and Hubs",
#       "apManagerInterfaceIp": "",
#       "tagCount": "2",
#       "type": "Cisco Catalyst 3850-48U-E Switch",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "roleSource": "MANUAL",
#       "managementIpAddress": "10.1.12.1",
#       "platformId": "WS-C3850-48U",
#       "locationName": "sj_campus",
#       "id": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#       "role": "ACCESS",
#       "bootDateTime": "2016-05-28 00:04:15",
#       "softwareVersion": "03.06.04.E",
#       "hostname": "CAMPUS-Access1",
#       "lastUpdateTime": 1498582916567,
#       "interfaceCount": "62",
#       "memorySize": "536870912",
#       "series": "Cisco Catalyst 3850 Series Ethernet Stackable Switch",
#       "snmpLocation": "",
#       "upTime": "175 days, 0:00:54.84",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     },
#     {
#       "macAddress": "24:e9:b3:3f:b1:80",
#       "lastUpdated": "2017-06-27 17:01:44",
#       "location": "3f9205b3-f452-4067-ac46-8493aff2afb4",
#       "lineCardCount": "14",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FXS1825Q1PA",
#       "instanceUuid": "30d39b18-9ada-4148-ad6c-2ee20975b845",
#       "snmpContact": "",
#       "lineCardId": "99629b7d-b558-4776-8258-c9059507e6ba, 98ba3828-2464-4c02-b64f-c9106fe15574, d1e8a963-9851-4afb-a044-884343c870a3, d606ceea-b457-4f3f-8b70-c2f528387df6, cd773cbf-68fc-4ffb-8a12-3efb96ece3e9, 9e721ea9-2e17-47d4-8f8f-666653ae5998, d609b8e3-0409-4139-9075-7420b4a955f0, ce5bcbca-2cfc-4185-9f9d-8f3b59b0d49d, ee0865ba-b064-4b80-a59c-85d8d3959981, 0e074792-676d-42b8-aca3-dcbc40a0f349, 3578a12a-0746-4052-9380-3bea11fc6563, 5e5ade87-3f2b-4738-847f-920420ec8f0d, 2e1ee55f-7f7a-437e-b0c9-9eafeefc71f8, 129d546d-f482-4af0-83a9-8ddfd670c75d",
#       "family": "Switches and Hubs",
#       "apManagerInterfaceIp": "",
#       "tagCount": "2",
#       "type": "Cisco Catalyst 6503 Switch",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "roleSource": "MANUAL",
#       "managementIpAddress": "10.1.7.1",
#       "platformId": "WS-C6503-E",
#       "locationName": "conf_center",
#       "id": "30d39b18-9ada-4148-ad6c-2ee20975b845",
#       "role": "CORE",
#       "bootDateTime": "2016-08-01 15:55:13",
#       "softwareVersion": "15.2(1)SY1",
#       "hostname": "CAMPUS-Core1",
#       "lastUpdateTime": 1498582904844,
#       "interfaceCount": "56",
#       "memorySize": "1397215264",
#       "series": "Cisco Catalyst 6500 Series Switches",
#       "snmpLocation": "",
#       "upTime": "109 days, 8:08:47.24",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     },
#     {
#       "macAddress": "24:e9:b3:3f:b1:c0",
#       "lastUpdated": "2017-06-27 17:01:32",
#       "location": "3f9205b3-f452-4067-ac46-8493aff2afb4",
#       "lineCardCount": "13",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FXS1825Q1P8",
#       "instanceUuid": "1b329f52-95eb-44ad-9314-55932162ab86",
#       "snmpContact": "",
#       "lineCardId": "e9c05ad5-7927-47ed-a7bb-00dca4c6bc3a, 282a822c-2429-45fe-93c8-95471e2235a0, 9e4bd7b4-d275-427d-8939-8b777f473201, 4559fa5e-4014-4968-b836-5e57da42e401, fd0ef08b-1e15-4b4f-b2e5-e4c1c0e0359b, a1ac1cf6-6cb3-4705-b2d3-60413eea2f0f, e7d236a7-c4d9-45da-9bda-d8af714495f2, da5cf7c8-ee9e-44d4-afb9-b78a51c30292, 1872a219-ad03-47a4-971b-d200ef1aae66, 7bdf020a-8a5b-41c3-af97-7eafdd6f88fb, bcda7746-cd09-4a28-8c6b-74e1551f423d, 6c83d6e1-c2b4-41a6-9aab-b9c8714b81b5, 6ce7447b-b310-472d-9307-7696ba81c7c8",
#       "family": "Switches and Hubs",
#       "apManagerInterfaceIp": "",
#       "tagCount": "1",
#       "type": "Cisco Catalyst 6503 Switch",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "roleSource": "MANUAL",
#       "managementIpAddress": "10.1.10.1",
#       "platformId": "WS-C6503-E",
#       "locationName": "conf_center",
#       "id": "1b329f52-95eb-44ad-9314-55932162ab86",
#       "role": "CORE",
#       "bootDateTime": "2016-04-06 01:25:14",
#       "softwareVersion": "15.2(1)SY1",
#       "hostname": "CAMPUS-Core2",
#       "lastUpdateTime": 1498582892359,
#       "interfaceCount": "56",
#       "memorySize": "1397215264",
#       "series": "Cisco Catalyst 6500 Series Switches",
#       "snmpLocation": "",
#       "upTime": "226 days, 22:38:02.60",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     },
#     {
#       "roleSource": "MANUAL",
#       "lastUpdated": "2017-06-27 17:01:44",
#       "lineCardCount": "2",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FOX1524GV2Z",
#       "instanceUuid": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#       "snmpContact": "",
#       "lineCardId": "6ed4dd13-e223-4296-9ac2-5dc1a6e676ae, c1eb9026-abde-4461-abb3-7d1cda5b0927",
#       "family": "Switches and Hubs",
#       "hostname": "CAMPUS-Dist1",
#       "tagCount": "1",
#       "type": "Cisco Catalyst 4507R plus E Switch",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "managementIpAddress": "10.255.1.5",
#       "platformId": "WS-C4507R+E",
#       "softwareVersion": "03.02.00.XO",
#       "id": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#       "role": "CORE",
#       "bootDateTime": "2016-07-26 04:42:13",
#       "apManagerInterfaceIp": "",
#       "lastUpdateTime": 1498582904702,
#       "interfaceCount": "60",
#       "memorySize": "805306368",
#       "series": "Cisco Catalyst 4500 Series Switches",
#       "snmpLocation": "",
#       "upTime": "115 days, 19:22:08.43",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     },
#     {
#       "macAddress": "30:e4:db:25:75:3f",
#       "lastUpdated": "2017-06-27 17:01:25",
#       "lineCardId": "775a85cf-923a-4848-b608-a20684a67e9d, 2e7fb0e0-ca4a-4c6d-b492-06437878d6e1",
#       "lineCardCount": "2",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FOX1525G5S1",
#       "instanceUuid": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22",
#       "snmpContact": "",
#       "hostname": "CAMPUS-Dist2",
#       "family": "Switches and Hubs",
#       "apManagerInterfaceIp": "",
#       "tagCount": "1",
#       "type": "Cisco Catalyst 4507R plus E Switch",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "roleSource": "MANUAL",
#       "managementIpAddress": "10.1.11.1",
#       "platformId": "WS-C4507R+E",
#       "id": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22",
#       "role": "DISTRIBUTION",
#       "bootDateTime": "2015-11-17 14:52:13",
#       "softwareVersion": "03.04.00.SG",
#       "lastUpdateTime": 1498582885025,
#       "interfaceCount": "56",
#       "memorySize": "805306368",
#       "series": "Cisco Catalyst 4500 Series Switches",
#       "snmpLocation": "",
#       "upTime": "367 days, 9:12:46.03",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     },
#     {
#       "macAddress": "f4:4e:05:cf:2e:30",
#       "lastUpdated": "2017-06-27 17:01:32",
#       "lineCardId": "f84f1b1f-7341-417e-8ab9-6037cb2dff09, daa0ceb6-0383-4a22-829a-8337d4811456, 382dcfe9-971d-4109-bf59-6f9788c4333e, 03390efc-103d-4220-a540-2074c6829485, 4de117cc-badd-46ac-a747-5b14fd83d59e, 596fd2a8-7e3d-4b3c-ad0a-ffbb82122648",
#       "lineCardCount": "6",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FTX1842AHM2",
#       "instanceUuid": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7",
#       "snmpContact": "",
#       "hostname": "CAMPUS-Router1",
#       "family": "Routers",
#       "apManagerInterfaceIp": "",
#       "tagCount": "2",
#       "type": "Cisco 4451 Series Integrated Services Router",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "roleSource": "MANUAL",
#       "managementIpAddress": "10.1.2.1",
#       "platformId": "ISR4451-X/K9",
#       "id": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7",
#       "role": "BORDER ROUTER",
#       "bootDateTime": "2016-04-13 00:03:13",
#       "softwareVersion": "15.4(3)S",
#       "lastUpdateTime": 1498582892337,
#       "interfaceCount": "6",
#       "memorySize": "1728629512",
#       "series": "Cisco 4400 Series Integrated Services Routers",
#       "snmpLocation": "",
#       "upTime": "220 days, 0:03:46.17",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     },
#     {
#       "macAddress": "f4:4e:05:cf:2f:e0",
#       "lastUpdated": "2017-06-27 17:01:25",
#       "lineCardId": "5160d894-c2b8-4839-9600-d380867e5419, 85fb9da6-b2c0-4442-881e-d92c64fc091e, 6431ea3b-7707-4c36-a06d-4ca318d27ae0, ac440c1e-be74-491a-99d1-2dcf97f5053e, a030671f-8489-4e78-9145-f2c67873642d, 1cf7b911-1ee3-463a-a0aa-a1d42ed3aeb0",
#       "lineCardCount": "6",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FTX1842AHM1",
#       "instanceUuid": "55450140-de19-47b5-ae80-bfd741b23fd9",
#       "snmpContact": "",
#       "hostname": "CAMPUS-Router2",
#       "family": "Routers",
#       "apManagerInterfaceIp": "",
#       "tagCount": "0",
#       "type": "Cisco 4451 Series Integrated Services Router",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "roleSource": "MANUAL",
#       "managementIpAddress": "10.1.4.2",
#       "platformId": "ISR4451-X/K9",
#       "id": "55450140-de19-47b5-ae80-bfd741b23fd9",
#       "role": "CORE",
#       "bootDateTime": "2015-08-31 05:08:13",
#       "softwareVersion": "15.4(3)S",
#       "lastUpdateTime": 1498582885081,
#       "interfaceCount": "6",
#       "memorySize": "1728629512",
#       "series": "Cisco 4400 Series Integrated Services Routers",
#       "snmpLocation": "",
#       "upTime": "445 days, 18:58:51.74",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     },
#     {
#       "macAddress": "a4:93:4c:fb:a2:e0",
#       "lastUpdated": "2017-06-27 17:01:56",
#       "tunnelUdpPort": "16666",
#       "collectionStatus": "In Progress",
#       "serialNumber": "FCW1630L0JG",
#       "instanceUuid": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3",
#       "snmpContact": "",
#       "family": "Wireless Controller",
#       "apManagerInterfaceIp": "",
#       "hostname": "Campus-WLC-5508",
#       "tagCount": "1",
#       "type": "Cisco 5508 Wireless LAN Controller",
#       "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#       "roleSource": "MANUAL",
#       "managementIpAddress": "10.1.14.2",
#       "platformId": "AIR-CT5508-K9",
#       "id": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3",
#       "upTime": "497 days, 2:27:52.95",
#       "bootDateTime": "2015-07-10 04:27:22",
#       "softwareVersion": "8.1.14.16",
#       "lastUpdateTime": 1498582916082,
#       "interfaceCount": "12",
#       "memorySize": "1025646592",
#       "series": "Cisco 5500 Series Wireless LAN Controllers",
#       "snmpLocation": "",
#       "role": "ACCESS",
#       "reachabilityStatus": "Unreachable",
#       "reachabilityFailureReason": ""
#     }
#   ]
# }

# %% [markdown]
# ### Displaying data
#
# Now print out a subset of the attributes.  Define a format string that can be used for both the heading and the data.
#
# - UseCase: Print out a comma sepparated list of attributes for importing into an asset management system

# %%
# define a formating string
formatstring='{ip:<16s} {name:<30s} {software:<16s} {serial:<20s}'

# print a heading
print(formatstring.format(ip="IP Address", 
                          name="Device Name", 
                          software="Software Version",
                         serial="Serial Number"))

# print each of the nework devices.  network_devices is a list of objects with attributes, not a python dict
for network_device in network_devices.response:
    print(formatstring.format(ip=network_device.managementIpAddress, 
                                 name=network_device.hostname,
                                 software=network_device.softwareVersion,
                             serial=network_device.serialNumber))
# Out:
# IP Address       Device Name                    Software Version Serial Number
# 165.10.1.39      AHEC-2960C1                    15.2(2.5.72)E4   FOC1637Y3FJ
# 10.1.14.3        AP7081.059f.19ca               8.1.14.16        FGL1548S2YF
# 10.2.1.17        Branch-Access1                 12.2(55)SE3      FOC1537W1ZY
# 10.2.2.1         Branch-Router1                 15.2(4)M6a       FTX1840ALC1
# 10.2.2.2         Branch-Router2                 15.2(4)M6a       FTX1840ALBY
# 218.1.100.100    Branch2-Router.yourdomain.com  15.2(4)M6a       FTX1840ALC0
# 10.1.12.1        CAMPUS-Access1                 03.06.04.E       FOC1703V36B
# 10.1.7.1         CAMPUS-Core1                   15.2(1)SY1       FXS1825Q1PA
# 10.1.10.1        CAMPUS-Core2                   15.2(1)SY1       FXS1825Q1P8
# 10.255.1.5       CAMPUS-Dist1                   03.02.00.XO      FOX1524GV2Z
# 10.1.11.1        CAMPUS-Dist2                   03.04.00.SG      FOX1525G5S1
# 10.1.2.1         CAMPUS-Router1                 15.4(3)S         FTX1842AHM2
# 10.1.4.2         CAMPUS-Router2                 15.4(3)S         FTX1842AHM1
# 10.1.14.2        Campus-WLC-5508                8.1.14.16        FCW1630L0JG

# %% [markdown]
# <font color=blue>
# <hr>
# <h2> Challenge </h2>
# Either insert a cell or modify the cell above to change the attributes that are printed out.
# <hr>
# </font>

# %% [markdown]
# ## Getting a Specific resource
#
# Now find a specific device and make a request for a single device

# %%
# look for a specific access device which is a 3850
try:
    # one line list comprehension
    deviceId = [net_dev.id for net_dev in network_devices.response 
                 if net_dev.role =="ACCESS" and  "3850-" in net_dev.type ][0]
    print ("Success, found id:{id}".format(id=deviceId))
except keyError:
    print ("FAIL: no suitable device found")
# Out:
# Success, found id:5b5ea8da-8c23-486a-b95e-7429684d25fc

# %% [markdown]
# This id can be used to return all the information about a single device.  Device id are important as the uniquely identify the device.  They are used in many API calls to perform an action on a device.  For example to assign a tag or a location for a device, you would need to know the ```id```.

# %%
network_device = apic.networkdevice.getNetworkDeviceById(id=deviceId)
print (json.dumps(apic.serialize(network_device), indent=2))
# Out:
# {
#   "version": "1.0",
#   "response": {
#     "macAddress": "f0:29:29:5c:30:e2",
#     "lastUpdated": "2017-06-27 17:01:56",
#     "location": "811ca696-a959-423e-b6d2-2506eba4410a",
#     "lineCardCount": "2",
#     "collectionStatus": "In Progress",
#     "serialNumber": "FOC1703V36B",
#     "instanceUuid": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#     "snmpContact": "",
#     "lineCardId": "4e3ad63f-36ac-4807-b2a9-e377ffc3b503, 2afe376a-b613-4695-82ba-3ed0030c37e6",
#     "family": "Switches and Hubs",
#     "apManagerInterfaceIp": "",
#     "tagCount": "2",
#     "type": "Cisco Catalyst 3850-48U-E Switch",
#     "inventoryStatusDetail": "<status><general code=\"SYNC\"/></status>",
#     "roleSource": "MANUAL",
#     "managementIpAddress": "10.1.12.1",
#     "platformId": "WS-C3850-48U",
#     "locationName": "sj_campus",
#     "id": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#     "role": "ACCESS",
#     "bootDateTime": "2016-05-28 00:04:15",
#     "softwareVersion": "03.06.04.E",
#     "hostname": "CAMPUS-Access1",
#     "lastUpdateTime": 1498582916567,
#     "interfaceCount": "62",
#     "memorySize": "536870912",
#     "series": "Cisco Catalyst 3850 Series Ethernet Stackable Switch",
#     "snmpLocation": "",
#     "upTime": "175 days, 0:00:54.84",
#     "reachabilityStatus": "Unreachable",
#     "reachabilityFailureReason": ""
#   }
# }

# %% [markdown]
# ### Get Network-device by management IP address
# Looking a device up by id is challenging as you may not always know the id.  It is often the case you know the management IP address (or serialnumber) and want to get the id of the device, or some other attributes (e.g. version of code).
#
# - UseCase: a function to allow the user to enter the IP address of a network-device and perform some other action based on the id.

# %%
# looks up a network device by ipaddress, and returns the id attribute
def ipToDeviceId(ipAddress):
    ip_network_device = apic.networkdevice.getNetworkDeviceByIp(ipAddress=ipAddress)
    return ip_network_device.response.id

# we are cheating here as we are just picking the IP address from earlier
# this is just to illustrate the use of a known ip address
ipAddress=network_device.response.managementIpAddress
id1 = ipToDeviceId(ipAddress)
print ("Example1: %s" % id1)

# now use a specific IP address.  You can change this to one of the examples above
ipAddress="218.1.100.100"
id2 = ipToDeviceId(ipAddress)
print ("Example1: %s" % id2)
# Out:
# Example1: 5b5ea8da-8c23-486a-b95e-7429684d25fc
# Example1: d337811b-d371-444c-a49f-9e2791f955b4

# %% [markdown]
# <font color=blue>
# <h2> Challenge </h2>
# Write some code to get all network-devices running IOS "15.2(4)M6a"
# </font>

# %% [markdown]
# ## Host data store
# This call show the hosts connected to the network.
#
# - UseCase: find my host

# %%
hosts = apic.host.getHosts()
print(json.dumps(apic.serialize(hosts), indent=4))
# Out:
# {
#     "version": "1.0",
#     "response": [
#         {
#             "hostMac": "00:24:d7:43:59:d8",
#             "lastUpdated": "1479514114932",
#             "hostType": "wireless",
#             "id": "48cdeb9b-b412-491e-a80c-7ec5bbe98167",
#             "connectedNetworkDeviceId": "cd6d9b24-839b-4d58-adfe-3fdf781e1782",
#             "source": "200",
#             "vlanId": "600",
#             "connectedAPMacAddress": "68:bc:0c:63:4a:b0",
#             "connectedNetworkDeviceIpAddress": "10.1.14.3",
#             "pointOfAttachment": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3",
#             "pointOfPresence": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3",
#             "subType": "UNKNOWN",
#             "connectedAPName": "AP7081.059f.19ca",
#             "hostIp": "10.1.15.117"
#         },
#         {
#             "connectedInterfaceName": "GigabitEthernet1/0/47",
#             "hostMac": "5c:f9:dd:52:07:78",
#             "lastUpdated": "1479514299803",
#             "hostType": "wired",
#             "id": "f624d4f3-0ab9-4ae3-b09d-62051edbd8f3",
#             "connectedNetworkDeviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#             "source": "200",
#             "connectedInterfaceId": "7075521d-4d7b-4218-92f9-79b60e054635",
#             "vlanId": "200",
#             "connectedNetworkDeviceIpAddress": "10.2.1.17",
#             "subType": "UNKNOWN",
#             "hostIp": "10.2.1.22"
#         },
#         {
#             "connectedInterfaceName": "GigabitEthernet1/0/47",
#             "hostMac": "e8:9a:8f:7a:22:99",
#             "lastUpdated": "1479513914455",
#             "hostType": "wired",
#             "id": "572d4065-abd8-4b97-bfc3-ab5ee13f6c08",
#             "connectedNetworkDeviceId": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#             "source": "200",
#             "connectedInterfaceId": "6e4e5ae6-6045-4060-9038-1a64d5a101cc",
#             "vlanId": "200",
#             "connectedNetworkDeviceIpAddress": "10.1.12.1",
#             "subType": "UNKNOWN",
#             "hostIp": "10.1.12.20"
#         }
#     ]
# }

# %% [markdown]
# Lookup a device by ipaddress (macAddress, hostname).
# Can also use connectedInterfaceName and connectedNetworkDeviceIpAddress

# %%
# lookup host by IP address
host=apic.host.getHosts(hostIp="10.2.1.22").response[0]

print("host: {ip} {mac}: DEVICE{deviceIp} {interface}".format(
                        ip=host.hostIp,
                        mac=host.hostMac,
                        deviceIp=host.connectedNetworkDeviceIpAddress,
                        interface=host.connectedInterfaceName   ))
# Out:
# host: 10.2.1.22 5c:f9:dd:52:07:78: DEVICE10.2.1.17 GigabitEthernet1/0/47

# %% [markdown]
# <font color=blue>
# <h2> Challenge </h2>
# Write some code to get the IOS version of the device a host is connected to.
# </font>

# %% [markdown]
# ### interfaces
#
# Look at the interfaces that the device above is connected to.  Get switch port utilization

# %%
host=apic.host.getHosts(hostIp="10.2.1.22").response[0]
deviceId =host.connectedNetworkDeviceId
interfaces = apic.interface.getInterfaceByDeviceId(deviceId=deviceId).response

# %%
print (json.dumps(apic.serialize(interfaces), indent=4))
# Out:
# [
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:81",
#         "status": "up",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10101",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "FullDuplex",
#         "instanceUuid": "05186c34-2ed8-4db4-bba3-ac9c2b68ad90",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "1000000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/1",
#         "id": "05186c34-2ed8-4db4-bba3-ac9c2b68ad90",
#         "vlanId": "200",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "access",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:8f",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10115",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "081661e5-b284-49ef-9e33-7d4dadae6ce6",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/15",
#         "id": "081661e5-b284-49ef-9e33-7d4dadae6ce6",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:90",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10116",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "094bcd08-ae02-4c2e-9a31-a22db0d05e12",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/16",
#         "id": "094bcd08-ae02-4c2e-9a31-a22db0d05e12",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:b4",
#         "status": "down",
#         "mediaType": "Not",
#         "ospfSupport": "false",
#         "ifIndex": "10152",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "15334580-1b6c-4e98-8358-9a773d683ea2",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/52",
#         "id": "15334580-1b6c-4e98-8358-9a773d683ea2",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:9f",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10131",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "15d91ddb-c0e7-4aee-b3db-f470e4b25d54",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/31",
#         "id": "15d91ddb-c0e7-4aee-b3db-f470e4b25d54",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:95",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10121",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "15ef968a-cfb6-42e6-9ad8-0d56051e14e0",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/21",
#         "id": "15ef968a-cfb6-42e6-9ad8-0d56051e14e0",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:93",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10119",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "1eece065-ebab-490c-a642-f6e71e4919bf",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/19",
#         "id": "1eece065-ebab-490c-a642-f6e71e4919bf",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:9d",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10129",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "215475b9-db41-4776-8dd1-2738c6ce47fa",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/29",
#         "id": "215475b9-db41-4776-8dd1-2738c6ce47fa",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:86",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10106",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "225725b6-718c-491e-bb43-2214d5e754d6",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/6",
#         "id": "225725b6-718c-491e-bb43-2214d5e754d6",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:9e",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10130",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "25f1e32c-a948-47c9-a4e9-fa97f56a6ce2",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/30",
#         "id": "25f1e32c-a948-47c9-a4e9-fa97f56a6ce2",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:8b",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10111",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "289ddf2d-3784-4747-ad35-a718a01f749a",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/11",
#         "id": "289ddf2d-3784-4747-ad35-a718a01f749a",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:b1",
#         "status": "down",
#         "mediaType": "Not",
#         "ospfSupport": "false",
#         "ifIndex": "10149",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "2b44333c-c309-4d7d-a123-55b70c9da836",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/49",
#         "id": "2b44333c-c309-4d7d-a123-55b70c9da836",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:8e",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10114",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "2bb1dcd0-813f-4f78-adba-2339c457c275",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/14",
#         "id": "2bb1dcd0-813f-4f78-adba-2339c457c275",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:8d",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10113",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "3da19a29-9ba3-41ed-a40b-1c5caba681ee",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/13",
#         "id": "3da19a29-9ba3-41ed-a40b-1c5caba681ee",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:9a",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10126",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "4489bdae-76d5-4113-b771-cc11a63094b3",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/26",
#         "id": "4489bdae-76d5-4113-b771-cc11a63094b3",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:9c",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10128",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "472d2e81-d81e-495e-b0dd-51271f890f08",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/28",
#         "id": "472d2e81-d81e-495e-b0dd-51271f890f08",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "macAddress": "64:a0:e7:d4:9b:b7",
#         "status": "down",
#         "ospfSupport": "false",
#         "speed": "100000",
#         "ifIndex": "12002",
#         "adminStatus": "DOWN",
#         "vlanId": "",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "portName": "FastEthernet0",
#         "instanceUuid": "4b4e2940-5a17-4331-a018-9056c96ea8a5",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "isisSupport": "false",
#         "className": "EthrntPrtclEndpntExtndd",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "interfaceType": "Physical",
#         "id": "4b4e2940-5a17-4331-a018-9056c96ea8a5",
#         "portType": "Ethernet Port",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:ad",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10145",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "52ad5a69-f7f9-46bf-8ab8-b51952c62b88",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/45",
#         "id": "52ad5a69-f7f9-46bf-8ab8-b51952c62b88",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:a0",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10132",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "548220af-8439-4ea5-a635-884cd454b283",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/32",
#         "id": "548220af-8439-4ea5-a635-884cd454b283",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:84",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10104",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "557523d3-86cc-45ee-a69b-4eb0d6d36ac6",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/4",
#         "id": "557523d3-86cc-45ee-a69b-4eb0d6d36ac6",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:91",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10117",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "55d06f42-17a2-4d69-b61b-19c2c790b804",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/17",
#         "id": "55d06f42-17a2-4d69-b61b-19c2c790b804",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:a2",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10134",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "5aef9486-e55b-46e8-85e9-b6a47b11ea8e",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/34",
#         "id": "5aef9486-e55b-46e8-85e9-b6a47b11ea8e",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:a4",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10136",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "5f2b6f3b-1c69-4394-8d39-137db2ef8401",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/36",
#         "id": "5f2b6f3b-1c69-4394-8d39-137db2ef8401",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:98",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10124",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "61ac58c7-0d5c-4cba-b882-ab5b96d06bae",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/24",
#         "id": "61ac58c7-0d5c-4cba-b882-ab5b96d06bae",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:96",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10122",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "62f031ed-ace0-4a3c-9875-07d883a39463",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/22",
#         "id": "62f031ed-ace0-4a3c-9875-07d883a39463",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:a7",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10139",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "63321c94-d3d3-475f-bfb8-7ecc4eb6609e",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/39",
#         "id": "63321c94-d3d3-475f-bfb8-7ecc4eb6609e",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:85",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10105",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "6516417a-8bda-4a6d-b683-9e4100d945e5",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/5",
#         "id": "6516417a-8bda-4a6d-b683-9e4100d945e5",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:c1",
#         "status": "up",
#         "ospfSupport": "false",
#         "ifIndex": "200",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "instanceUuid": "6fffed35-e0ac-4ec9-9712-04b61cfe2e5a",
#         "interfaceType": "Virtual",
#         "speed": "1000000",
#         "portType": "Ethernet SVI",
#         "portMode": "routed",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "Vlan200",
#         "ipv4Address": "10.2.1.17",
#         "ipv4Mask": "255.255.255.0",
#         "vlanId": "200",
#         "isisSupport": "false",
#         "className": "VLANInterfaceExtended",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "id": "6fffed35-e0ac-4ec9-9712-04b61cfe2e5a",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:af",
#         "status": "up",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10147",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "FullDuplex",
#         "instanceUuid": "7075521d-4d7b-4218-92f9-79b60e054635",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "100000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/47",
#         "id": "7075521d-4d7b-4218-92f9-79b60e054635",
#         "vlanId": "200",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "access",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:ab",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10143",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "74ac2987-f217-4496-a162-5d47a37fa6da",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/43",
#         "id": "74ac2987-f217-4496-a162-5d47a37fa6da",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "macAddress": "64:a0:e7:d4:9b:c0",
#         "status": "down",
#         "ospfSupport": "false",
#         "ifIndex": "1",
#         "adminStatus": "UP",
#         "vlanId": "1",
#         "serialNo": "FOC1537W1ZY",
#         "speed": "1000000",
#         "portName": "Vlan1",
#         "instanceUuid": "766d8f67-5aa0-473b-a5bf-582e54d2aae0",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "isisSupport": "false",
#         "className": "VLANInterfaceExtended",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "interfaceType": "Virtual",
#         "id": "766d8f67-5aa0-473b-a5bf-582e54d2aae0",
#         "portType": "Ethernet SVI",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:87",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10107",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "794d2c89-42c2-4212-a07d-726f24575fdf",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/7",
#         "id": "794d2c89-42c2-4212-a07d-726f24575fdf",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:ae",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10146",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "80fe4066-231d-43d0-beb5-7aafd3fb719d",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/46",
#         "id": "80fe4066-231d-43d0-beb5-7aafd3fb719d",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:88",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10108",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "838233ad-0542-4b96-b7e2-3e04b7ef1616",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/8",
#         "id": "838233ad-0542-4b96-b7e2-3e04b7ef1616",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:94",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10120",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "8657ff17-9dd9-402b-ab0c-b7ccf697bafd",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/20",
#         "id": "8657ff17-9dd9-402b-ab0c-b7ccf697bafd",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:89",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10109",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "91ff6267-ecbd-4fd1-86dd-5cd765980a3e",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/9",
#         "id": "91ff6267-ecbd-4fd1-86dd-5cd765980a3e",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:a8",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10140",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "9366287d-fac7-4381-a68a-080c5764a030",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/40",
#         "id": "9366287d-fac7-4381-a68a-080c5764a030",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:99",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10125",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "965dba91-361f-4e0c-8a56-f6f91ec734f5",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/25",
#         "id": "965dba91-361f-4e0c-8a56-f6f91ec734f5",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:b3",
#         "status": "down",
#         "mediaType": "Not",
#         "ospfSupport": "false",
#         "ifIndex": "10151",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "a596261b-cd36-4c05-b18f-e7fea8a07ce5",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/51",
#         "id": "a596261b-cd36-4c05-b18f-e7fea8a07ce5",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:82",
#         "status": "up",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10102",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "FullDuplex",
#         "instanceUuid": "a6355c85-3577-4922-bfe5-1c08456b7cae",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "1000000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/2",
#         "id": "a6355c85-3577-4922-bfe5-1c08456b7cae",
#         "vlanId": "200",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "access",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:97",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10123",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "abed8e62-a403-4d89-b1e6-f30586b5894d",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/23",
#         "id": "abed8e62-a403-4d89-b1e6-f30586b5894d",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:a1",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10133",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "ac1498de-3ae3-406b-bb43-43ba54a76dce",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/33",
#         "id": "ac1498de-3ae3-406b-bb43-43ba54a76dce",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:a9",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10141",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "b110cc56-587e-484f-ba51-8c5a4441c745",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/41",
#         "id": "b110cc56-587e-484f-ba51-8c5a4441c745",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:b2",
#         "status": "down",
#         "mediaType": "Not",
#         "ospfSupport": "false",
#         "ifIndex": "10150",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "b4d85885-5d54-414c-83ad-98c526150feb",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/50",
#         "id": "b4d85885-5d54-414c-83ad-98c526150feb",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:83",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10103",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "b63ea026-239d-40fd-816b-5fa4e34478ba",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/3",
#         "id": "b63ea026-239d-40fd-816b-5fa4e34478ba",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:8c",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10112",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "b7e31a6c-49a3-4dc1-8f78-976763f8b9a5",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/12",
#         "id": "b7e31a6c-49a3-4dc1-8f78-976763f8b9a5",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:b0",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10148",
#         "adminStatus": "DOWN",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "c0bddd72-4acc-4db8-8cb5-63343db0bc87",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/48",
#         "id": "c0bddd72-4acc-4db8-8cb5-63343db0bc87",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:a6",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10138",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "d168ca5e-782d-474c-bfbe-a19415f17491",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/38",
#         "id": "d168ca5e-782d-474c-bfbe-a19415f17491",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:8a",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10110",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "d17e9da9-a759-4585-b465-db41c894150a",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/10",
#         "id": "d17e9da9-a759-4585-b465-db41c894150a",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:a5",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10137",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "d6899cff-1437-494b-92a8-96f94388a255",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/37",
#         "id": "d6899cff-1437-494b-92a8-96f94388a255",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:9b",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10127",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "d9afc00f-b02c-4e8e-a9eb-fdf169cad3bd",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/27",
#         "id": "d9afc00f-b02c-4e8e-a9eb-fdf169cad3bd",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:aa",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10142",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "e7d7f7fe-ae93-4e11-9cd5-80b0471e9eca",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/42",
#         "id": "e7d7f7fe-ae93-4e11-9cd5-80b0471e9eca",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:a3",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10135",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "ef1eeceb-68fc-428f-8009-d4356aa6bff9",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/35",
#         "id": "ef1eeceb-68fc-428f-8009-d4356aa6bff9",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:ac",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10144",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "f70fef4d-5c6c-4db4-9c00-6e3aff73ee0a",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/44",
#         "id": "f70fef4d-5c6c-4db4-9c00-6e3aff73ee0a",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     },
#     {
#         "description": "",
#         "macAddress": "64:a0:e7:d4:9b:92",
#         "status": "down",
#         "mediaType": "10/100/1000BaseTX",
#         "ospfSupport": "false",
#         "ifIndex": "10118",
#         "adminStatus": "UP",
#         "serialNo": "FOC1537W1ZY",
#         "duplex": "AutoNegotiate",
#         "instanceUuid": "f7184975-8c4b-4a8f-88f6-bfe783d0e5ba",
#         "nativeVlanId": "1",
#         "interfaceType": "Physical",
#         "speed": "10000",
#         "portType": "Ethernet Port",
#         "lastUpdated": "2017-06-27 17:01:56.367",
#         "deviceId": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#         "portName": "GigabitEthernet1/0/18",
#         "id": "f7184975-8c4b-4a8f-88f6-bfe783d0e5ba",
#         "vlanId": "1",
#         "isisSupport": "false",
#         "className": "SwitchPort",
#         "series": "Cisco Catalyst 2960 Series Switches",
#         "portMode": "dynamic_auto",
#         "pid": "WS-C2960S-48LPS-L"
#     }
# ]

# %%
# get a list of portName,  speed and status
[(port.portName, port.speed, port.status)
                 for port in interfaces
                 if port.interfaceType == 'Physical']
# Out:
# [('GigabitEthernet1/0/1', '1000000', 'up'),
#  ('GigabitEthernet1/0/15', '10000', 'down'),
#  ('GigabitEthernet1/0/16', '10000', 'down'),
#  ('GigabitEthernet1/0/52', '10000', 'down'),
#  ('GigabitEthernet1/0/31', '10000', 'down'),
#  ('GigabitEthernet1/0/21', '10000', 'down'),
#  ('GigabitEthernet1/0/19', '10000', 'down'),
#  ('GigabitEthernet1/0/29', '10000', 'down'),
#  ('GigabitEthernet1/0/6', '10000', 'down'),
#  ('GigabitEthernet1/0/30', '10000', 'down'),
#  ('GigabitEthernet1/0/11', '10000', 'down'),
#  ('GigabitEthernet1/0/49', '10000', 'down'),
#  ('GigabitEthernet1/0/14', '10000', 'down'),
#  ('GigabitEthernet1/0/13', '10000', 'down'),
#  ('GigabitEthernet1/0/26', '10000', 'down'),
#  ('GigabitEthernet1/0/28', '10000', 'down'),
#  ('FastEthernet0', '100000', 'down'),
#  ('GigabitEthernet1/0/45', '10000', 'down'),
#  ('GigabitEthernet1/0/32', '10000', 'down'),
#  ('GigabitEthernet1/0/4', '10000', 'down'),
#  ('GigabitEthernet1/0/17', '10000', 'down'),
#  ('GigabitEthernet1/0/34', '10000', 'down'),
#  ('GigabitEthernet1/0/36', '10000', 'down'),
#  ('GigabitEthernet1/0/24', '10000', 'down'),
#  ('GigabitEthernet1/0/22', '10000', 'down'),
#  ('GigabitEthernet1/0/39', '10000', 'down'),
#  ('GigabitEthernet1/0/5', '10000', 'down'),
#  ('GigabitEthernet1/0/47', '100000', 'up'),
#  ('GigabitEthernet1/0/43', '10000', 'down'),
#  ('GigabitEthernet1/0/7', '10000', 'down'),
#  ('GigabitEthernet1/0/46', '10000', 'down'),
#  ('GigabitEthernet1/0/8', '10000', 'down'),
#  ('GigabitEthernet1/0/20', '10000', 'down'),
#  ('GigabitEthernet1/0/9', '10000', 'down'),
#  ('GigabitEthernet1/0/40', '10000', 'down'),
#  ('GigabitEthernet1/0/25', '10000', 'down'),
#  ('GigabitEthernet1/0/51', '10000', 'down'),
#  ('GigabitEthernet1/0/2', '1000000', 'up'),
#  ('GigabitEthernet1/0/23', '10000', 'down'),
#  ('GigabitEthernet1/0/33', '10000', 'down'),
#  ('GigabitEthernet1/0/41', '10000', 'down'),
#  ('GigabitEthernet1/0/50', '10000', 'down'),
#  ('GigabitEthernet1/0/3', '10000', 'down'),
#  ('GigabitEthernet1/0/12', '10000', 'down'),
#  ('GigabitEthernet1/0/48', '10000', 'down'),
#  ('GigabitEthernet1/0/38', '10000', 'down'),
#  ('GigabitEthernet1/0/10', '10000', 'down'),
#  ('GigabitEthernet1/0/37', '10000', 'down'),
#  ('GigabitEthernet1/0/27', '10000', 'down'),
#  ('GigabitEthernet1/0/42', '10000', 'down'),
#  ('GigabitEthernet1/0/35', '10000', 'down'),
#  ('GigabitEthernet1/0/44', '10000', 'down'),
#  ('GigabitEthernet1/0/18', '10000', 'down')]

# %%
import re
def atoi(text):
    return int(text) if text.isdigit() else text

# natural sort for interfaces
def natural_sort(interfacelist):
    return sorted(interfacelist, key=lambda port: [ atoi(c) for c in re.split('(\d+)', port.portName)])

[(port.portName, port.speed, port.status)
        for port in natural_sort(interfaces)
            if port.interfaceType == 'Physical']
# Out:
# [('FastEthernet0', '100000', 'down'),
#  ('GigabitEthernet1/0/1', '1000000', 'up'),
#  ('GigabitEthernet1/0/2', '1000000', 'up'),
#  ('GigabitEthernet1/0/3', '10000', 'down'),
#  ('GigabitEthernet1/0/4', '10000', 'down'),
#  ('GigabitEthernet1/0/5', '10000', 'down'),
#  ('GigabitEthernet1/0/6', '10000', 'down'),
#  ('GigabitEthernet1/0/7', '10000', 'down'),
#  ('GigabitEthernet1/0/8', '10000', 'down'),
#  ('GigabitEthernet1/0/9', '10000', 'down'),
#  ('GigabitEthernet1/0/10', '10000', 'down'),
#  ('GigabitEthernet1/0/11', '10000', 'down'),
#  ('GigabitEthernet1/0/12', '10000', 'down'),
#  ('GigabitEthernet1/0/13', '10000', 'down'),
#  ('GigabitEthernet1/0/14', '10000', 'down'),
#  ('GigabitEthernet1/0/15', '10000', 'down'),
#  ('GigabitEthernet1/0/16', '10000', 'down'),
#  ('GigabitEthernet1/0/17', '10000', 'down'),
#  ('GigabitEthernet1/0/18', '10000', 'down'),
#  ('GigabitEthernet1/0/19', '10000', 'down'),
#  ('GigabitEthernet1/0/20', '10000', 'down'),
#  ('GigabitEthernet1/0/21', '10000', 'down'),
#  ('GigabitEthernet1/0/22', '10000', 'down'),
#  ('GigabitEthernet1/0/23', '10000', 'down'),
#  ('GigabitEthernet1/0/24', '10000', 'down'),
#  ('GigabitEthernet1/0/25', '10000', 'down'),
#  ('GigabitEthernet1/0/26', '10000', 'down'),
#  ('GigabitEthernet1/0/27', '10000', 'down'),
#  ('GigabitEthernet1/0/28', '10000', 'down'),
#  ('GigabitEthernet1/0/29', '10000', 'down'),
#  ('GigabitEthernet1/0/30', '10000', 'down'),
#  ('GigabitEthernet1/0/31', '10000', 'down'),
#  ('GigabitEthernet1/0/32', '10000', 'down'),
#  ('GigabitEthernet1/0/33', '10000', 'down'),
#  ('GigabitEthernet1/0/34', '10000', 'down'),
#  ('GigabitEthernet1/0/35', '10000', 'down'),
#  ('GigabitEthernet1/0/36', '10000', 'down'),
#  ('GigabitEthernet1/0/37', '10000', 'down'),
#  ('GigabitEthernet1/0/38', '10000', 'down'),
#  ('GigabitEthernet1/0/39', '10000', 'down'),
#  ('GigabitEthernet1/0/40', '10000', 'down'),
#  ('GigabitEthernet1/0/41', '10000', 'down'),
#  ('GigabitEthernet1/0/42', '10000', 'down'),
#  ('GigabitEthernet1/0/43', '10000', 'down'),
#  ('GigabitEthernet1/0/44', '10000', 'down'),
#  ('GigabitEthernet1/0/45', '10000', 'down'),
#  ('GigabitEthernet1/0/46', '10000', 'down'),
#  ('GigabitEthernet1/0/47', '100000', 'up'),
#  ('GigabitEthernet1/0/48', '10000', 'down'),
#  ('GigabitEthernet1/0/49', '10000', 'down'),
#  ('GigabitEthernet1/0/50', '10000', 'down'),
#  ('GigabitEthernet1/0/51', '10000', 'down'),
#  ('GigabitEthernet1/0/52', '10000', 'down')]

# %%
len([port.portName for port in natural_sort(interfaces)
                 if port.interfaceType == 'Physical'
                    and port.status == 'up'])
# Out:
# 3

# %% [markdown]
# <font color=blue>
# <h2> Challenge </h2>
# Calculate the percentage utilization (active ports) for the switch above.
# </font>
